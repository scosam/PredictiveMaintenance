# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp
import os
import seaborn as sns

# %% [markdown]
# # Import Data

# %%
wd = os.getcwd()

# Machine Meta Data 
mach_meta = pd.read_csv(wd + '\\data\\PdM_machines.csv')

# Error Logs
err_log = pd.read_csv(wd + '\\data\\PdM_errors.csv')

# Failure Logs
fail_log = pd.read_csv(wd + '\\data\\PdM_failures.csv')

# Maintenance Logs
maint_log = pd.read_csv(wd + '\\data\\PdM_maint.csv')

# Sensor Data
sens_data = pd.read_csv(wd + '\\data\\PdM_telemetry.csv')

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Machine Data

# %%
mach_meta.describe(include='all')
# Out:
#          machineID   model         age
# count   100.000000     100  100.000000
# unique         NaN       4         NaN
# top            NaN  model3         NaN
# freq           NaN      35         NaN
# mean     50.500000     NaN   11.330000
# std      29.011492     NaN    5.856974
# min       1.000000     NaN    0.000000
# 25%      25.750000     NaN    6.750000
# 50%      50.500000     NaN   12.000000
# 75%      75.250000     NaN   16.000000
# max     100.000000     NaN   20.000000

# %% [markdown]
# There are 100 machines, 4 different models, and machine ages ranging from brand new to 20 years old. Let's look at the break down of the machine ages for each type of model.

# %%
print(mach_meta[['model', 'age']].groupby('model').describe())

fig = plt.figure(figsize=(10,8))
sns.swarmplot(x='model', y='age', data=mach_meta, 
              order=['model1', 'model2', 'model3', 'model4'], size=10)
plt.show()
# Out:
#          age
#        count       mean       std  min    25%   50%    75%   max
# model
# model1  16.0  12.250000  5.385165  2.0   9.25  14.0  16.00  20.0
# model2  17.0  12.764706  5.847322  2.0  10.00  14.0  18.00  20.0
# model3  35.0  12.028571  5.607168  1.0   8.50  14.0  17.00  20.0
# model4  32.0   9.343750  6.099230  0.0   4.00   9.5  14.25  20.0

# %% [markdown]
# Although there are less models of type 1 and 2 the overall distributions of the four models are remarkably similar. Three of the models have a mean age of 12 and a standard deviation of 5.5. Model 4 is slightly different since the units are younger in general, mean age of 9, but the standard deviation is similar to the others.

# %% [markdown]
# ## Failure & Maintenance Logs

# %%
maint_log['maintenance'] = 1
maint_log.drop(columns=['comp'], inplace=True)

fail_log['failure'] = 1

#verify that more than one failure or maintenance does not occur 
#on the same date for the same computer

# %%
# Combine failure and maintenance logs based on the machine ID and datetime
maint_log.merge(fail_log, how='outer', on=['datetime', 'machineID'])
# Out:
#                  datetime  machineID  maintenance  failure
# 0     2014-06-01 06:00:00          1          1.0      NaN
# 1     2014-07-16 06:00:00          1          1.0      NaN
# 2     2014-07-31 06:00:00          1          1.0      NaN
# 3     2014-12-13 06:00:00          1          1.0      NaN
# 4     2015-01-05 06:00:00          1          1.0      1.0
# ...                   ...        ...          ...      ...
# 3381  2015-01-02 03:00:00         83          NaN      1.0
# 3382  2015-01-02 03:00:00         86          NaN      1.0
# 3383  2015-01-02 03:00:00         87          NaN      1.0
# 3384  2015-01-02 03:00:00         94          NaN      1.0
# 3385  2015-01-02 03:00:00         99          NaN      1.0
#
# [3386 rows x 4 columns]

# %%
maint_log.merge(fail_log, how='outer')
# Out:
#                  datetime  machineID  maintenance  failure
# 0     2014-06-01 06:00:00          1          1.0      NaN
# 1     2014-07-16 06:00:00          1          1.0      NaN
# 2     2014-07-31 06:00:00          1          1.0      NaN
# 3     2014-12-13 06:00:00          1          1.0      NaN
# 4     2015-01-05 06:00:00          1          1.0      1.0
# ...                   ...        ...          ...      ...
# 3381  2015-01-02 03:00:00         83          NaN      1.0
# 3382  2015-01-02 03:00:00         86          NaN      1.0
# 3383  2015-01-02 03:00:00         87          NaN      1.0
# 3384  2015-01-02 03:00:00         94          NaN      1.0
# 3385  2015-01-02 03:00:00         99          NaN      1.0
#
# [3386 rows x 4 columns]
